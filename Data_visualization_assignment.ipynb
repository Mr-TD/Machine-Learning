# %% [markdown]
# # In this assignment students have to transform iris data into 3 dimensions and plot a 3d chart with transformed dimensions and colour each data point with specific class.

# %%
# import library
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from sklearn import datasets

# %%
# read dataset from sklearn
iris = datasets.load_iris()
iris.data.shape
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
X = iris.data
Y = iris.target

# To getter a better understanding of interaction of the dimensions
# plot the first three PCA dimensions
fig = plt.figure(1, figsize=(8, 6))
ax = Axes3D(fig, elev=-150, azim=10)

X_reduced = PCA(n_components=3).fit_transform(iris.data) # n_components=3 for 3d
#X_reduced = PCA(n_components=2).fit_transform(iris.data) # n_components=2 for 2d

# X_reduced.shape -->(150, 3)

ax.scatter(X_reduced[:, 0], X_reduced[:, 1], X_reduced[:, 2], c=Y,
           cmap=plt.cm.winter)

ax.set_title("First three PCA directions")

ax.set_xlabel("1st eigenvector")
# ax.w_xaxis.set_ticklabels([]) # for hide numbers on the X axis

ax.set_ylabel("2nd eigenvector")
# ax.w_yaxis.set_ticklabels([]) # for hide numbers on the Y axis

ax.set_zlabel("3rd eigenvector")
# ax.w_zaxis.set_ticklabels([])# for hide numbers on the Z axis


plt.show()

# %%
iris.data.shape
# Out:
# (150, 4)

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
X_reduced.shape
# Out:
# (150, 3)
